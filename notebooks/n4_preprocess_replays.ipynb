# %% [markdown]
# Test ability to preprocess data for efficiently finding goot replays

# %%
# insert code here to input a file and get data including
# chars, stage, I'll need to think of other important attributes
